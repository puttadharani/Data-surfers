# %% [markdown]
# <a href="https://colab.research.google.com/github/puttadharani/Data-surfers/blob/main/my_1st_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **<center>PROJECT- HOTEL BOOKING ANALSYS</center>**

# %% [markdown]
# ##### **Project Type**    - EDA CAPSTONE
# ##### **Contribution**    - individual
# ##### **Team Member 1 - Dharani Putta**

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Worked on a Hotel bookings analysis Project that contains a .csv file with 3820480 cells in it. This dataset contains a total of rows 119390 and 32 columns. In this, I have divided data manipulation workflow into three category Data Collection, Data cleaning and manipulation, and EDA(Exploratory Data Analysis). As Further moved i.e Data collection first step is to find different columns which are done by coding .head(), .tail(), .info(), .describe(), .columns, .index, .size, .shape and some other methods used for data collection, some of the names of the columns are updated here i.e hotel,is_canceled,lead_time,arrival_date_year,arrival_date_month,arrival_date_week_number,arrival_date_day_of_month,stays_in_weekend_nights.As further moved I found the unique values of each column and generate a list in tabular form and also check the dataset type of each columns’ find some columns, not inaccurate data types which correct it later done in Data cleaning part and as well as duplicates data items must be removed as I encountered duplicates items equal to 1023808 (31994 rows × 32 columns) which is dropped from dataset later using .drop_duplicates()
#
#
# Before visualizing any data from the data set data wrangling should be performed. For that, I checked for null values of all the columns. After checking, when we get a column with more null values, we drop that column by using the 'drop' method. When we find the minimal number of null values, fill these null values with necessary values as per requirement by using .fillna()
#
#
# Different charts are used for data visualization to attain better insights and business objectives.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/puttadharani/Data-surfers/tree/main

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions! This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. Explore and analyze the data to discover important factors that govern the bookings.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Analyse the data on bookings of City Hotel and Resort Hotel to gain insights on the different factors that affect the booking. This is undertaken as an individual project.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
path='/content/drive/MyDrive/Hotel Bookings.csv'
df=pd.read_csv(path)
df=pd.read_csv('/content/drive/MyDrive/Hotel Bookings.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# viewing first 10 rows
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
#viewing last 10 rows
df.tail(10)
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 119380  City Hotel            0         44               2017
# 119381  City Hotel            0        188               2017
# 119382  City Hotel            0        135               2017
# 119383  City Hotel            0        164               2017
# 119384  City Hotel            0         21               2017
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 119380             August                        35
# 119381             August                        35
# 119382             August                        35
# 119383             August                        35
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print('Rows count=',df.index.size)
row_count=df.index.size
print('Columns count=',df.columns.size)
column_count=df.columns.size
print('size of data frame:',df.size)#returns no.of elements
# Out:
# Rows count= 119390
# Columns count= 32
# size of data frame: 3820480

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
#duplicate values dataframe
duplicate_values_df=df[df.duplicated()]
duplicate_values_df.head(10)
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 5    Resort Hotel            0         14               2015
# 22   Resort Hotel            0         72               2015
# 43   Resort Hotel            0         70               2015
# 138  Resort Hotel            1          5               2015
# 200  Resort Hotel            0          0               2015
# 219  Resort Hotel            1          1               2015
# 256  Resort Hotel            0         91               2015
# 261  Resort Hotel            0         30               2015
# 353  Resort Hotel            0         98               2015
# 372  Resort Hotel            0         40               2015
#
#     arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 5                 July                        27                          1
# 22                July                        27                          1
# ...

# %%
print('Number of duplicate values in dataframe=',duplicate_values_df.size)
# Out:
# Number of duplicate values in dataframe= 1023808

# %%
#creating a data frame with no duplicate values
non_duplicate_df=df.drop_duplicates()
non_duplicate_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %%
# finding number of unique values in each column of non_duplicate_df
non_duplicate_df.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
null_values=df.isnull()==True
df.fillna(np.nan,inplace=True)
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Visualizing the missing 
miss_values_count_df=df.isnull().sum().sort_values(ascending=False)[:].reset_index().rename(columns={'index':'Columns',0:'Null_values'})
miss_values_count_df
# Out:
#                            Columns  Null_values
# 0                          company       112593
# 1                            agent        16340
# 2                          country          488
# 3                         children            4
# 4               reserved_room_type            0
# 5               assigned_room_type            0
# 6                  booking_changes            0
# 7                     deposit_type            0
# 8                            hotel            0
# 9           previous_cancellations            0
# 10            days_in_waiting_list            0
# 11                   customer_type            0
# 12                             adr            0
# 13     required_car_parking_spaces            0
# 14       total_of_special_requests            0
# 15              reservation_status            0
# 16  previous_bookings_not_canceled            0
# 17               is_repeated_guest            0
# 18                     is_canceled            0
# ...

# %%
miss_values_count_df1=pd.DataFrame(df.isna().sum().sort_values(ascending=False))
miss_values_count_df1
# Out:
#                                      0
# company                         112593
# agent                            16340
# country                            488
# children                             4
# reserved_room_type                   0
# assigned_room_type                   0
# booking_changes                      0
# deposit_type                         0
# hotel                                0
# previous_cancellations               0
# days_in_waiting_list                 0
# customer_type                        0
# adr                                  0
# required_car_parking_spaces          0
# total_of_special_requests            0
# reservation_status                   0
# previous_bookings_not_canceled       0
# is_repeated_guest                    0
# is_canceled                          0
# distribution_channel                 0
# market_segment                       0
# meal                                 0
# babies                               0
# ...

# %%
#visualization of miss_values_count_df
miss_values_count_df1.plot.bar(figsize=(20,10),color='blue')
plt.title('Null values count of each column')
plt.xlabel('Column names')
plt.ylabel('Number of null values')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# I have explored various columns regarding booking information including some information about guests in this .csv file. It includes information such as when the booking was made, days of stay, the number of adults, children, and/or babies, and the number of available parking spaces, etc. among other things. The dataset contains a total of 119390 rows and 32 columns. Dataset Contains duplicated items i.e 31944 which is removed later. In this dataset, data types of every column i.e Int, float, string, can be seen and observed that some column’s data types are not accurate and removed later and it was mandatory to drop null values to get accurate numbers. I have also found unique values in every column which showed actual values in every column.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# I have the following variables in data:<br>
# 'hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
# 'arrival_date_month', 'arrival_date_week_number',
# 'arrival_date_day_of_month', 'stays_in_weekend_nights',
# 'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
# 'country', 'market_segment', 'distribution_channel',
# 'is_repeated_guest', 'previous_cancellations','previous_bookings_not_canceled', 'reserved_room_type',
# 'assigned_room_type', 'booking_changes', 'deposit_type', 'agent','company', 'days_in_waiting_list', 'customer_type', 'adr','required_car_parking_spaces',total_of_special_requests',
# 'reservation_status', 'reservation_status_date'

# %% [markdown]
# The variables represent the data of customers, their bookings and additional information.<br>
# **hotel**- types of hotels<br>
# **is_canceled**- tells whether a booking is cancelled or not<br>
# **lead_time**'- Number of days between booking and actual arrival of guests<br>
# **arrival_date_year**- The year of arrival of guests<br>
# **arrival_date_month**- The month of arrival of guests<br> **arrival_date_week_number**- The week of arrival of guests<br>
# **arrival_date_day_of_month**- The date of arrival of guests<br>
# **stays_in_weekend_nights**- number of days stayed in weekend nights<br>
# **stays_in_week_nights**- number of days stayed in week nights<br>
# **adults**- represents number of adults stayed in hotel rooms<br>
# **children**- represents number of children stayed in hotel rooms<br>
# **babies**- represents number of babies
#  stayed in hotel rooms<br>
# **meal**- tells what type of meal is served in hotels<br> **country**- tells people from which countries visited the hotel<br>
# **market_segment**- modes of bookings available<br> **distribution_channel**- mode of booking customer opted for<br>
# **is_repeated_guest**- specifies if the guest has visited the hotel previously<br>
# **previous_cancellations**- specifies if any bookings are cancelled previously<br>
# **previous_bookings_not_canceled**- specifies if any previously bookings are cancelled or not<br>
# **reserved_room_type**- type of room reserved by customers<br>
# **assigned_room_type**- type of room assigned by hotels<br>
# **booking_changes**- specifies if there is any change in bookings<br>
# **deposit_type**- mentions type of deposit made by customers<br>
# **agent**- specifies the agent code<br>
# **company**- specifies company code<br>
# **days_in_waiting_list**- Number of days in waiting list<br> **customer_type**- specifies type of customer<br>
# **adr**- Average daily rate of the hotel<br> **required_car_parking_spaces**- number of parking spaces required by guests<br>
# **total_of_special_requests**- number of special requests made by customers<br>
# **reservation_status**- specifies reservation status of room bookings<br>
# **reservation_status_date**- date of check-out

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
column_list=[df.columns]

for i in column_list:
  print(df[i].nunique())
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %%
df.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
column_list
# Out:
# [Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#         'arrival_date_month', 'arrival_date_week_number',
#         'arrival_date_day_of_month', 'stays_in_weekend_nights',
#         'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#         'country', 'market_segment', 'distribution_channel',
#         'is_repeated_guest', 'previous_cancellations',
#         'previous_bookings_not_canceled', 'reserved_room_type',
#         'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#         'company', 'days_in_waiting_list', 'customer_type', 'adr',
#         'required_car_parking_spaces', 'total_of_special_requests',
#         'reservation_status', 'reservation_status_date'],
#        dtype='object')]

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %% [markdown]
# **QUESTION 1. What is the most_reserved room type & mode of booking?(along with data frame & visualization)**

# %%
#calculating the different number of room types booked by customers.
reserved_room_type=df['reserved_room_type'].value_counts()
reserved_room_type=pd.DataFrame(reserved_room_type)
reserved_room_type
# Out:
#    reserved_room_type
# A               85994
# D               19201
# E                6535
# F                2897
# G                2094
# B                1118
# C                 932
# H                 601
# P                  12
# L                   6

# %%
#visualization of reserved_room_type
reserved_room_type.plot(kind='bar')
plt.title('Reservation of different room types')
plt.xlabel('Room types')
plt.ylabel('Number of reservations')
plt.show()

# %%
print('The most booked room type is "',reserved_room_type.index[0],'" with ',reserved_room_type['reserved_room_type'].max(),' bookings.')
# Out:
# The most booked room type is " A " with  85994  bookings.

# %%
#calculating the different number of room types booked by customers.
mode_of_bookings=df['market_segment'].dropna().value_counts()
mode_of_bookings=pd.DataFrame(mode_of_bookings)
mode_of_bookings
# Out:
#                market_segment
# Online TA               56477
# Offline TA/TO           24219
# Groups                  19811
# Direct                  12606
# Corporate                5295
# Complementary             743
# Aviation                  237
# Undefined                   2

# %%
#visualization of modes of bookings
from matplotlib.lines import MarkerStyle
mode_of_bookings.plot(figsize=(15,5),color='red')
plt.title('Representation of modes of booking')
plt.xlabel('Modes of booking')
plt.ylabel('Number of bookings')
plt.show()

# %%
print('The highest mode of booking is "',mode_of_bookings.index[0],'" with ',int(mode_of_bookings.max()),' bookings.')
# Out:
# The highest mode of booking is " Online TA " with  56477  bookings.

# %% [markdown]
# <b>QUESTION 2. What's the difference between "reserved_room_type" and "assigned_room_type"? and did hotels fulfill the customers expectations? if "yes" or "no" ,how can we improve? </b>

# %%
#counting assigned room types
assigned_room_type=df['assigned_room_type'].value_counts()
assigned_room_type=pd.DataFrame(assigned_room_type)
assigned_room_type
# Out:
#    assigned_room_type
# A               74053
# D               25322
# E                7806
# F                3751
# G                2553
# C                2375
# B                2163
# H                 712
# I                 363
# K                 279
# P                  12
# L                   1

# %%
#creating a list of assigned_room_types bookings
assigned_values=[i for i in df['assigned_room_type'].value_counts()]
print(assigned_values)

#creating a dictionary of assigned_room_types
assigned_rooms_dict=dict(zip(assigned_room_type.index,assigned_values))
print(assigned_rooms_dict)
# Out:
# [74053, 25322, 7806, 3751, 2553, 2375, 2163, 712, 363, 279, 12, 1]
# {'A': 74053, 'D': 25322, 'E': 7806, 'F': 3751, 'G': 2553, 'C': 2375, 'B': 2163, 'H': 712, 'I': 363, 'K': 279, 'P': 12, 'L': 1}

# %%
#creating a list of reserved_room_types bookings
reserved_values=[i for i in df['reserved_room_type'].value_counts()]
print(reserved_values)

#creating a dictionary of reserved_room_types
reserved_rooms_dict=dict(zip(reserved_room_type.index,reserved_values))
print(reserved_rooms_dict)
# Out:
# [85994, 19201, 6535, 2897, 2094, 1118, 932, 601, 12, 6]
# {'A': 85994, 'D': 19201, 'E': 6535, 'F': 2897, 'G': 2094, 'B': 1118, 'C': 932, 'H': 601, 'P': 12, 'L': 6}

# %%
#creating a list with reserved_rooms_dict and assigned_rooms_dict
rooms_list=[reserved_rooms_dict,assigned_rooms_dict]
print(rooms_list)

#creating a dataframe with reserved_rooms_dict and assigned_rooms_dict as columns
rooms_df=pd.DataFrame(rooms_list,index=['Reserved rooms','Assigned rooms'])
rooms_df
# Out:
# [{'A': 85994, 'D': 19201, 'E': 6535, 'F': 2897, 'G': 2094, 'B': 1118, 'C': 932, 'H': 601, 'P': 12, 'L': 6}, {'A': 74053, 'D': 25322, 'E': 7806, 'F': 3751, 'G': 2553, 'C': 2375, 'B': 2163, 'H': 712, 'I': 363, 'K': 279, 'P': 12, 'L': 1}]
#                     A      D     E     F     G     B     C    H   P  L      I  \
# Reserved rooms  85994  19201  6535  2897  2094  1118   932  601  12  6    NaN
# Assigned rooms  74053  25322  7806  3751  2553  2163  2375  712  12  1  363.0
#
#                     K
# Reserved rooms    NaN
# Assigned rooms  279.0

# %%
#visualization of diff_list
rooms_df.T.plot(kind='bar',figsize=(15,5))
plt.title('Reserved rooms and assigned rooms')
plt.xlabel('Room types')
plt.ylabel('Number of rooms')
plt.show()

# %%
#creating a dataframe with a new column that contains difference between reserved and assigned rooms count
difference_df=rooms_df.T
difference_df['Difference']=difference_df['Reserved rooms']-difference_df['Assigned rooms']
difference_df.T
# Out:
#                       A        D       E       F       G       B       C  \
# Reserved rooms  85994.0  19201.0  6535.0  2897.0  2094.0  1118.0   932.0
# Assigned rooms  74053.0  25322.0  7806.0  3751.0  2553.0  2163.0  2375.0
# Difference      11941.0  -6121.0 -1271.0  -854.0  -459.0 -1045.0 -1443.0
#
#                     H     P    L      I      K
# Reserved rooms  601.0  12.0  6.0    NaN    NaN
# Assigned rooms  712.0  12.0  1.0  363.0  279.0
# Difference     -111.0   0.0  5.0    NaN    NaN

# %%
#visualization of difference between reserved and assigned rooms count
difference_df['Difference'].plot(kind='bar',figsize=(15,5),color='brown')
plt.title('Difference between count of Reserved rooms and assigned rooms')
plt.xlabel('Room types')
plt.ylabel('Difference')
plt.show()

# %% [markdown]
# <b>Most of the hotels have met the customers expectations in terms of assigning reserved room types. But should also try to give their maximum to fulfill customers reservations.</b>

# %% [markdown]
# <b>QUESTION 3. How many customers made special requests & what foods were served in what quantities?</b>

# %%
#creating a new dataframe that contains data of special requests
special_requests=df[df['total_of_special_requests']!=0]
special_requests.head()
# Out:
#            hotel  is_canceled  lead_time  arrival_date_year  \
# 4   Resort Hotel            0         14               2015
# 5   Resort Hotel            0         14               2015
# 7   Resort Hotel            0          9               2015
# 8   Resort Hotel            1         85               2015
# 12  Resort Hotel            0         68               2015
#
#    arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 4                July                        27                          1
# 5                July                        27                          1
# 7                July                        27                          1
# 8                July                        27                          1
# 12               July                        27                          1
#
#     stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# ...

# %%
print(f'{special_requests.index.size} guests out of {df.index.size} guests made special requests.')
# Out:
# 49072 guests out of 119390 guests made special requests.

# %%
#creating a dataframe of number of requests made by number of people 
guests_requests=pd.DataFrame(df['total_of_special_requests'].value_counts())
guests_requests
# Out:
#    total_of_special_requests
# 0                      70318
# 1                      33226
# 2                      12969
# 3                       2497
# 4                        340
# 5                         40

# %%
print(df['total_of_special_requests'].sum() ,'Requests were made by',special_requests.index.size,'members.')
# Out:
# 68215 Requests were made by 49072 members.

# %%
requests_percentage=round((special_requests.index.size/df.index.size)*100,2)
print(f'{requests_percentage}% of the visitors made special requests.')
# Out:
# 41.1% of the visitors made special requests.

# %%
#creating a list of number of requests and number of people
requests=list(guests_requests['total_of_special_requests'][1:])
print(requests)
labels=list(guests_requests.index[1:])
labels
# Out:
# [33226, 12969, 2497, 340, 40]
# [1, 2, 3, 4, 5]

# %%
#visualization of number of requests along with number of people
myexplode = [0, 0, 0, 0,0.2]
plt.pie(requests,labels=labels,explode=myexplode)
plt.title('Pie chart representation number of requests made')
plt.legend()
plt.show()

# %%
# knowing what types of food was served in what quantities
df['meal'].value_counts()
# Out:
# BB           92310
# HB           14463
# SC           10650
# Undefined     1169
# FB             798
# Name: meal, dtype: int64

# %% [markdown]
# <b>QUESTION 4. In which month hotels had more number of visitors?</b>

# %%
# creating a dataframe that contains number of visitors in each month
monthly_count=df['arrival_date_month'].value_counts()
monthly_count=pd.DataFrame(monthly_count).T
monthly_count
# Out:
#                     August   July    May  October  April   June  September  \
# arrival_date_month   13877  12661  11791    11160  11089  10939      10508
#
#                     March  February  November  December  January
# arrival_date_month   9794      8068      6794      6780     5929

# %%
print(f'Hotels were booked the most in {monthly_count.index[0]} with a count of {int(monthly_count.max()[0])}')
# Out:
# Hotels were booked the most in arrival_date_month with a count of 13877

# %% [markdown]
# <b>QUESTION 5. Which months have highest no of cancellation?</b>

# %%
#creating a dataframe containing monthly cancellations records
cancellation_records=df[df['is_canceled']==1]
cancellation_records
cancellations_df=pd.DataFrame(cancellation_records['arrival_date_month'].value_counts()).T
cancellations_df
# Out:
#                     August  July   May  June  April  October  September  \
# arrival_date_month    5239  4742  4677  4535   4524     4246       4116
#
#                     March  February  December  November  January
# arrival_date_month   3149      2696      2371      2122     1807

# %%
print('cancellations were high in',cancellations_df.columns[0],'with a value of',cancellations_df.max()[0])
# Out:
# cancellations were high in August with a value of 5239

# %%
#creating a list of months
months=['January','February','March','April','May','June','July','August','September','October','November','December']

#creating a list of month wise number of bookings
bookings=[monthly_count[i][0] for i in months]

#creating a list of month wise number of cancellations
cancellations=[cancellations_df[i][0] for i in months]

# creating dictionaries of bookings and cancellations
first_bookings=dict(zip(months,bookings))
successful_cancellations=dict(zip(months,cancellations))

#creating a list of bookings and cancellations
final_bookings=[first_bookings,successful_cancellations]
final_bookings
# Out:
# [{'January': 5929,
#   'February': 8068,
#   'March': 9794,
#   'April': 11089,
#   'May': 11791,
#   'June': 10939,
#   'July': 12661,
#   'August': 13877,
#   'September': 10508,
#   'October': 11160,
#   'November': 6794,
#   'December': 6780},
#  {'January': 1807,
#   'February': 2696,
#   'March': 3149,
#   'April': 4524,
#   'May': 4677,
#   'June': 4535,
#   'July': 4742,
#   'August': 5239,
#   'September': 4116,
#   'October': 4246,
#   'November': 2122,
#   'December': 2371}]

# %%
#finding final successful bookings
successful_bookings=pd.DataFrame(final_bookings,index=['Bookings','Cancellations']).T
successful_bookings['Successful_bookings']=successful_bookings['Bookings']-successful_bookings['Cancellations']
successful_bookings.T
# Out:
#                      January  February  March  April    May   June   July  \
# Bookings                5929      8068   9794  11089  11791  10939  12661
# Cancellations           1807      2696   3149   4524   4677   4535   4742
# Successful_bookings     4122      5372   6645   6565   7114   6404   7919
#
#                      August  September  October  November  December
# Bookings              13877      10508    11160      6794      6780
# Cancellations          5239       4116     4246      2122      2371
# Successful_bookings    8638       6392     6914      4672      4409

# %% [markdown]
# Even after cancellations, August has highest number of bookings(8638)

# %% [markdown]
# **QUESTION 6. Which hotel booking is hightest in number?(resort hotel or city hotel)**

# %%
# checking hotel types wise bookings
df['hotel'].value_counts()
# Out:
# City Hotel      79330
# Resort Hotel    40060
# Name: hotel, dtype: int64

# %%
print('City hotels were booked the most and has a count of',df['hotel'].value_counts().max())
# Out:
# City hotels were booked the most and has a count of 79330

# %% [markdown]
# **QUESTION 7. What is the percentage of repeated guests?**

# %%
#checking the number of repeated guests
repeated_guests=dict(df['is_repeated_guest'].value_counts())
repeated_guests
# Out:
# {0: 115580, 1: 3810}

# %%
#calculating the percentage of repeated guests
percentage=round((repeated_guests[1]/df['is_repeated_guest'].size)*100,2)

# %%
print(f'Percentage of repeated guests: {percentage}%')
# Out:
# Percentage of repeated guests: 3.19%

# %% [markdown]
# **QUESTION 8. When did the guests visit the most? in weekend or weekday?**

# %%
#calculating the count of weekend and weekdays stays
weekend_stay=df['stays_in_weekend_nights'].sum()
week_nights_stay=df['stays_in_week_nights'].sum()
print('Weekend stays count=',weekend_stay)
print('Week nights stays count=',week_nights_stay)
# Out:
# Weekend stays count= 110746
# Week nights stays count= 298511

# %%
print('People stayed most in ',end='')
print('weekends')if(weekend_stay>week_nights_stay)else print('week_nights',end='')
# Out:
# People stayed most in week_nights

# %%
#finding the number of days stayed by number of people in week nights
count_of_stays=pd.DataFrame(df['stays_in_week_nights'].value_counts())
count_of_stays.rename(columns={'stays_in_week_nights':'Number_of_stays'},inplace=True)
count_of_stays
# Out:
#     Number_of_stays
# 2             33684
# 1             30310
# 3             22258
# 5             11077
# 4              9563
# 0              7645
# 6              1499
# 10             1036
# 7              1029
# 8               656
# 9               231
# 15               85
# 11               56
# 19               44
# 12               42
# 20               41
# 14               35
# 13               27
# 16               16
# 21               15
# 22                7
# 25                6
# 18                6
# 30                5
# 17                4
# 24                3
# 40                2
# 33                1
# 42                1
# 50                1
# 32                1
# 26                1
# 34                1
# 35                1
# 41                1

# %%
#visualization of week nights stay
plt.hist(df['stays_in_week_nights'],color='orange')
plt.title('Histogram representation of week nights stay')
plt.xlabel('Number of days of stay')
plt.ylabel('Number of stays')
plt.show()

# %% [markdown]
# **QUESTION 9. How many agents are there in total? Which Agent made the most bookings?**

# %%
#knowing number of bookings made by each agent
agent_bookings=pd.DataFrame(df['agent'].value_counts()).reset_index()
agent_bookings.rename(columns={'index':'Agent','agent':'Number of bookings'},inplace=True)
agent_bookings
# Out:
#      Agent  Number of bookings
# 0      9.0               31961
# 1    240.0               13922
# 2      1.0                7191
# 3     14.0                3640
# 4      7.0                3539
# ..     ...                 ...
# 328  289.0                   1
# 329  432.0                   1
# 330  265.0                   1
# 331   93.0                   1
# 332  304.0                   1
#
# [333 rows x 2 columns]

# %%
print('There are',agent_bookings.size,'agents.')
print('And Agent "',agent_bookings['Agent'][0],'" has made highest number of bookings-',agent_bookings['Number of bookings'].max())
# Out:
# There are 666 agents.
# And Agent " 9.0 " has made highest number of bookings- 31961

# %% [markdown]
# **QUESTION 10.What is the cancellation percentage of the Hotel bookings?**

# %%
#calculating cancellation percentage
cancellation_percentage=float((cancellations_df.T.sum()/df.index.size)*100)

# %%
print('Cancellations percentage=',round(cancellation_percentage,2),'%')
# Out:
# Cancellations percentage= 37.04 %

# %%
#visualizing bookings and cancellations percentages using a pie chart
plt.pie(x=[62.96,37.04],labels=['Successful bookings','Cancellations'],colors=['gold','silver'],autopct='%1.0f%%')
plt.title('Percentages of bookings and calculations')
plt.show()

# %% [markdown]
# **QUESTION 11. People of which countries stayed in hotels? which country's guests have visited most time?**

# %%
#finding the count of visitors from different countries
visitors_count=pd.DataFrame(df['country'].value_counts()).reset_index()
visitors_count.rename(columns={'index':'Country','country':'Number of people visited'},inplace=True)
visitors_count
# Out:
#     Country  Number of people visited
# 0       PRT                     48590
# 1       GBR                     12129
# 2       FRA                     10415
# 3       ESP                      8568
# 4       DEU                      7287
# ..      ...                       ...
# 172     DJI                         1
# 173     BWA                         1
# 174     HND                         1
# 175     VGB                         1
# 176     NAM                         1
#
# [177 rows x 2 columns]

# %%
#creating a list of countries that people came from
countries_list=list(visitors_count['Country'])

# %%
print('The hotels were booked by the people from the following',len(countries_list),'countries :',countries_list)
# Out:
# The hotels were booked by the people from the following 177 countries : ['PRT', 'GBR', 'FRA', 'ESP', 'DEU', 'ITA', 'IRL', 'BEL', 'BRA', 'NLD', 'USA', 'CHE', 'CN', 'AUT', 'SWE', 'CHN', 'POL', 'ISR', 'RUS', 'NOR', 'ROU', 'FIN', 'DNK', 'AUS', 'AGO', 'LUX', 'MAR', 'TUR', 'HUN', 'ARG', 'JPN', 'CZE', 'IND', 'KOR', 'GRC', 'DZA', 'SRB', 'HRV', 'MEX', 'EST', 'IRN', 'LTU', 'ZAF', 'BGR', 'NZL', 'COL', 'UKR', 'MOZ', 'CHL', 'SVK', 'THA', 'SVN', 'ISL', 'LVA', 'ARE', 'CYP', 'TWN', 'SAU', 'PHL', 'TUN', 'SGP', 'IDN', 'NGA', 'EGY', 'URY', 'LBN', 'PER', 'HKG', 'MYS', 'ECU', 'VEN', 'BLR', 'CPV', 'GEO', 'JOR', 'KAZ', 'CRI', 'GIB', 'MLT', 'OMN', 'AZE', 'KWT', 'MAC', 'QAT', 'IRQ', 'DOM', 'PAK', 'BIH', 'MDV', 'BGD', 'ALB', 'PRI', 'SEN', 'CMR', 'MKD', 'BOL', 'PAN', 'GNB', 'TJK', 'VNM', 'CUB', 'ARM', 'JEY', 'LBY', 'AND', 'MUS', 'LKA', 'CIV', 'JAM', 'KEN', 'FRO', 'MNE', 'TZA', 'BHR', 'CAF', 'SUR', 'PRY', 'BRB', 'GTM', 'UZB', 'MCO', 'GAB', 'GHA', 'ZWE', 'ETH', 'TMP', 'LIE', 'GGY', 'SYR', 'BEN', 'GLP', 'SLV', 'A
# ...

# %%
x=list(visitors_count['Country'].head(10))
y=list(visitors_count['Number of people visited'].head(10))
v=plt.barh(x,y,color='pink')
plt.bar_label(v)
plt.title('Top 10 countries with highest number of visitors.')
plt.xlabel('Number of bookings')
plt.ylabel('Countries')
plt.show()

# %%
print('Hotels had more visitors from "',visitors_count['Country'][0],'" with',visitors_count['Number of people visited'][0],'bookings')
# Out:
# Hotels had more visitors from " PRT " with 48590 bookings

# %% [markdown]
# **QUESTION 12. Which year had the highest bookings?**

# %%
#finding yearly bookings
yearly_bookings=pd.DataFrame(df['arrival_date_year'].value_counts())
yearly_bookings.rename(columns={'index':'year','Number of bookings':'Arrival_date_year'},inplace=True)
yearly_bookings
# Out:
#       arrival_date_year
# 2016              56707
# 2017              40687
# 2015              21996

# %%
print('Bookings were high in',yearly_bookings['year'][0])
# Out:
# Bookings were high in 2016

# %% [markdown]
# **QUESTION 13. What is the most served meal hotel-wise?**

# %%
#creating a dataframe of city_hotels
city_hotels=pd.DataFrame()
city_hotels=df[df['hotel']=='City Hotel']
city_hotels
# Out:
#              hotel  is_canceled  lead_time  arrival_date_year  \
# 40060   City Hotel            0          6               2015
# 40061   City Hotel            1         88               2015
# 40062   City Hotel            1         65               2015
# 40063   City Hotel            1         92               2015
# 40064   City Hotel            1        100               2015
# ...            ...          ...        ...                ...
# 119385  City Hotel            0         23               2017
# 119386  City Hotel            0        102               2017
# 119387  City Hotel            0         34               2017
# 119388  City Hotel            0        109               2017
# 119389  City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 40060                July                        27
# 40061                July                        27
# 40062                July                        27
# ...

# %%
#creating a dataframe of resort_hotels
resort_hotels=pd.DataFrame()
resort_hotels=df[df['hotel']=='Resort Hotel']
resort_hotels
# Out:
#               hotel  is_canceled  lead_time  arrival_date_year  \
# 0      Resort Hotel            0        342               2015
# 1      Resort Hotel            0        737               2015
# 2      Resort Hotel            0          7               2015
# 3      Resort Hotel            0         13               2015
# 4      Resort Hotel            0         14               2015
# ...             ...          ...        ...                ...
# 40055  Resort Hotel            0        212               2017
# 40056  Resort Hotel            0        169               2017
# 40057  Resort Hotel            0        204               2017
# 40058  Resort Hotel            0        211               2017
# 40059  Resort Hotel            0        161               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0                   July                        27                          1
# ...

# %%
#calculating meal count in city hotels
city_meals=pd.DataFrame(city_hotels['meal'].value_counts())
city_meals=city_meals
city_meals
# Out:
#      meal
# BB  62305
# SC  10564
# HB   6417
# FB     44

# %%
#visualizing meal count in city hotels
sns.heatmap(city_meals,cmap='coolwarm',annot=True)
plt.title('Heat map representation of meals served in city hotels')
# Out:
# Text(0.5, 1.0, 'Heat map representation of meals served in city hotels')

# %%
#calculating meal count in resort hotels
resort_meals=pd.DataFrame(resort_hotels['meal'].value_counts())
resort_meals
# Out:
#             meal
# BB         30005
# HB          8046
# Undefined   1169
# FB           754
# SC            86

# %%
#visualizing meal count in city hotels
sns.heatmap(resort_meals,cmap='coolwarm',annot=True)
plt.title('Heat map representation of meals served in resort hotels')
plt.show()

# %%
print('The most served meal in city hotels is',city_meals.index[0])
print('The most served meal in resort hotels is',resort_meals.index[0])
# Out:
# The most served meal in city hotels is BB
# The most served meal in resort hotels is BB

# %% [markdown]
# **QUESTION 14. How many parking spaces were required?**

# %%
# creating a dataframe of bookings that needed parking spaces
parking_df=pd.DataFrame(df[df['required_car_parking_spaces']!=0])
parking_df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 25      Resort Hotel            0         78               2015
# 29      Resort Hotel            0         99               2015
# 53      Resort Hotel            0          3               2015
# 54      Resort Hotel            0          1               2015
# 55      Resort Hotel            0          1               2015
# ...              ...          ...        ...                ...
# 119158    City Hotel            0        180               2017
# 119198    City Hotel            0         27               2017
# 119236    City Hotel            0        216               2017
# 119281    City Hotel            0        158               2017
# 119329    City Hotel            0         30               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 25                   July                        27
# 29                   July                        27
# ...

# %%
#calculating number of spaces required
number_of_parkings=parking_df['required_car_parking_spaces'].sum()

# %%
print(number_of_parkings,'parking spaces were required')
# Out:
# 7464 parking spaces were required

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# **I have done a few manipulations in the Data.**
#
#
# **----Addition of columns----**
#
#
# I have seen that there are a few columns required in data for analysis purposes which can be evaluated from the given columns.
#
#
# a) **difference_df:** This column will help us to know the difference between reserved rooms and assigned rooms. I created this new column by subtracting the values of assigned rooms from the values of reserved rooms.
#
#
#
#
# **----Dropping null values---**
#
#
# a) Dropped null values to get accurate calculations.
#
#
#
#
# **----Replace of Values in columns----**
#
#
# a)**Replaced NaN values with 0** replaced NaN values with 0 using numpy function.
#
#
# **----Changes in the data type of values in columns----**
# changed the data frame and columns values into lists and dictionaries for further calculations and plotting
#
#
#
#
# **----Removed is_null values & duplicate entries----**
#
#
# a)Before visualizing any data from the data set I had to do data wrangling. Data cleaning is mandatory to get desired results.
# For that, I have checked the null values in all the columns. After checking, when I encountered these null values ,dropped them by using the 'drop_duplicates()' method. In this way, when we find a minimal number of null values, fill these null values with necessary values as per requirement by using .fillna().
#
#
# b) In the same way, I checked if there is any duplicity in data & found that there are some rows that have duplicate data. So removed those rows from the data set by using the .drop_duplicates() method and have created a new data frame.
#
#
# Created new data frames that contain only specific data related to the question using pd.DataFrame().
#
#
#
#
# **And now, the data is cleaned**

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Reservation of different room types

# %%
# Chart - 1 visualization code
reserved_room_type.plot(kind='bar')
plt.title('Reservation of different room types')
plt.xlabel('Room types')
plt.ylabel('Number of reservations')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Vertical bar charts are useful to compare different categorical or discrete variables in bars and with spaces in between them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart, it is found that type "A" rooms were booked the most.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these gained insights help creating a positive business impact and  there no insights that lead to negative growth as there are no negative values in the above chart.

# %% [markdown]
# #### Chart - 2 Representation of modes of booking.

# %%
# Chart - 2 visualization code
from matplotlib.lines import MarkerStyle
mode_of_bookings.plot(figsize=(15,5),color='red')
plt.title('Representation of modes of booking')
plt.xlabel('Modes of booking')
plt.ylabel('Number of bookings')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Line graph is helpful to emphasize changes in values for one variable for continuous values of a second variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The highest mode of booking is " Online TA " with  market_segment    56477

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these gained insights help creating a positive business impact and  there no insights that lead to negative growth as there are no negative values in the above chart.

# %% [markdown]
# #### Chart - 3 Reserved rooms and assigned rooms

# %%
# Chart - 3 visualization code
rooms_df.T.plot(kind='bar',figsize=(15,5))
plt.title('Reserved rooms and assigned rooms')
plt.xlabel('Room types')
plt.ylabel('Number of rooms')
# Out:
# Text(0, 0.5, 'Number of rooms')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To compare the values of both reserved and assigned rooms. Bar plot gives an easy eye comfort visualization that helps people understand comparision very easily.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# There is much difference between reserved rooms and assigned rooms of type 'A'.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes , the gained insights help creating a positive business impact. There is a insight that lead to negative growth.The hotels could not assigned the requested number of reserved rooms of type 'A'.

# %% [markdown]
# #### Chart - 4 Difference between count of Reserved rooms and assigned rooms

# %%
# Chart - 4 visualization code
difference_df['Difference'].plot(kind='bar',figsize=(15,5))
plt.title('Difference between count of Reserved rooms and assigned rooms')
plt.xlabel('Room types')
plt.ylabel('Difference')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Vertical bar charts are useful to compare different categorical or discrete variables in bars and with spaces in between them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The hotels could not assign the total number of reserved rooms of type 'A'.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help to create a positive business impact. There is an insight that led to negative growth. By using the above visualization the hotel can try to fulfill the required number of reserved rooms.

# %% [markdown]
# #### Chart - 5 histogram representation number of requests week nights stay

# %%
#visualization of week nights stay
plt.hist(df['stays_in_week_nights'],color='orange')
plt.title('Histogram representation of week nights stay')
plt.xlabel('Number of days of stay')
plt.ylabel('Number of stays')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# histogram is helpful in summarizing discrete or continuous data that are measured on an interval scale

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# People stayed more in the interval of 0-5 days.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights will help creating a positive business impact. There are no insights that lead to negative growth

# %% [markdown]
# ####Chart - 6 Pie chart representation number of successful bookings and cancellations.

# %%
#visualizing bookings and cancellations percentages using a pie chart
plt.pie(x=[62.96,37.04],labels=['Successful bookings','Cancellations'],colors=['gold','silver'],autopct='%1.0f%%')
plt.title('Percentages of bookings and calculations')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# Pie chart is more helpful in situation if the sum of the individual parts add up to a meaningful whole, and is built for visualizing how each part contributes to that whole.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# It is observed that cancellations are 37.04% which is almost equal to 1/3rd of total number of bookings.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact? Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There are insights that may lead to negative growth. By using the above visualization the hotels can try to implement steps that may reduce cancellations.

# %% [markdown]
# #### Chart - 7 Pie chart representation number of requests made

# %%
myexplode = [0, 0, 0, 0,0.2]
plt.pie(requests,labels=labels,explode=myexplode)
plt.title('Pie chart representation number of requests made')
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# pie chart is more helpful in situation if the sum of the individual parts add up to a meaningful whole, and is built for visualizing how each part contributes to that whole.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# more number of people have made '1' request.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help creating a positive business impact. There are no insights that lead to negative growth. By using the above visualization the hotel can try to show  and improve it's customer friendly services.

# %% [markdown]
# #### Chart - 8 Heat map representation of meals served in city hotels.

# %%
# Chart - 8 visualization code
sns.heatmap(city_meals,cmap='coolwarm',annot=True)
plt.title('Heat map representation of meals served in city hotels')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To know which areas get the most attention, a heat map shows you in a visual way that’s easy to assimilate and make decisions from.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# BB type food was most served in city hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help creating a positive business impact. There are no insights that lead to negative growth. By using the above visualization the city hotels can try to advertise it's food serving capacity and quality.

# %% [markdown]
# #### Chart - 9 Heat map representation of meals served in resort hotels

# %%
# Chart - 9 visualization code
sns.heatmap(resort_meals,cmap='coolwarm',annot=True)
plt.title('Heat map representation of meals served in resort hotels')
# Out:
# Text(0.5, 1.0, 'Heat map representation of meals served in resort hotels')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To know which areas get the most attention, a heat map shows you in a visual way that’s easy to assimilate and make decisions from.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# BB type food was most served in resort hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights help creating a positive business impact. There are no insights that lead to negative growth. By using the above visualization the resort hotels can try to advertise it's food serving capacity and quality.

# %% [markdown]
# #### Chart - 10 Correlation Heatmap of dataframe columns

# %%
# Correlation Heatmap visualization code
corr_df =df[['lead_time','previous_cancellations', 'previous_bookings_not_canceled',
             'booking_changes', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces', 'total_of_special_requests']].corr()
f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(corr_df, annot = True, fmt='.2f', annot_kws={'size': 10},  vmax=1, square=True, cmap="BuPu")
plt.title('correlation heatmap of dataframe columns')
# Out:
# Text(0.5, 1.0, 'correlation heatmap of dataframe columns')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation heatmaps can be used to find potential relationships between variables and to understand the strength of these relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Highest corelation value between axis is 0.17(positive) & lowest corelation value between the axis is -0.12(negative).

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# 1.Increase occupancy rate: One solution to this objective could be to analyze historical data on occupancy rates and identify trends and patterns in booking behavior. This could involve identifying peak booking periods and adjusting pricing and promotions accordingly to maximize occupancy during those times.
#
# 2.Another solution could be to analyze customer feedback and reviews to identify areas for improvement in customer satisfaction, which can lead to increased bookings and repeat business.
#
# 3.Improve guest experience: One solution to this objective could be to analyze customer feedback and reviews to identify common issues or complaints and address them directly. This could involve improving amenities, upgrading facilities or rooms, or providing better customer service.
#
# 4.Another solution could be to analyze data on guest behavior and preferences, such as which amenities or services are most commonly used, to tailor the guest experience to their needs and preferences.
#
# 5.Increase revenue: One solution to this objective could be to analyze revenue data to identify areas of opportunity for upselling or cross-selling, such as offering guests additional services or amenities during their stay.
#
# 6.Another solution could be to analyze pricing data to identify opportunities for dynamic pricing, such as adjusting room rates based on demand or seasonality.
#
# 7.Reduce costs: One solution to this objective could be to analyze operational data to identify areas for cost savings, such as reducing energy consumption or optimizing staffing levels.
#
# 8.Another solution could be to analyze procurement data to identify opportunities for cost savings on supplies or equipment.
#
# Overall, the key to successfully using data analysis to achieve business objectives in the hotel industry is to start with clear goals and then use data to identify specific areas for improvement and develop targeted solutions to address them.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. City hotels were booked the most and have a count of 79330
#
#
# 2. The highest mode of booking is " Online TA " with  market_segment 56477
#
#
# 3. The most booked room type is " A " with  85994  bookings.
#
#
# 4. Bookings were high in 2016.
#
#
# 5. Hotels were booked the most in the month of August.
#
#
# 6. Cancellations were high in August. Total cancellation rate of the Hotel bookings=37.04%
#
#
# 7. Even after cancellations, August has the highest number of bookings(8638)
#
#
# 8. There are 333 agents and Agent " 9.0 " has made the highest number of bookings
#
#
# 9. The hotels were booked by people from 177 countries.
#
#
# 10. Hotels had more visitors from PRT with 48590 bookings.
#
#
# 11. Percentage of repeated guests: 3.19%
#
#
# 12. The most-served meal in city hotels is BB
# The most served meal in resort hotels is BB.
#
#
# 13. 7416 parking spaces were required.
#
#
# 14. Most of the hotels have met the customers' expectations in terms of assigning reserved room types. But should also try to give their maximum to fulfill customers' reservations.

# %% [markdown]
# ### <center>Yay! I have analyzed the data successfully and completed our EDA Capstone Project.<br> And also reached  the first stepping stone of becoming a data scientist</center>
